# %% [markdown]
# **Imports**

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

from sklearn.metrics import (
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    ConfusionMatrixDisplay
)

# %% [markdown]
# **Logistic Regression Class (FROM SCRATCH)**

# %%
class LogisticRegressionOVA:
    def __init__(self, alpha=0.1, iterations=1000, num_labels=10):
        self.alpha = alpha
        self.iterations = iterations
        self.num_labels = num_labels
        self.all_theta = None

    # --------------------------------------------------
    # Sigmoid Function
    # --------------------------------------------------
    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    # --------------------------------------------------
    # Cost Function 
    # --------------------------------------------------
    def compute_cost(self, X, y, theta):
        m = len(y)
        h = self.sigmoid(X @ theta)

        cost = (-1 / m) * np.sum(
            y * np.log(h + 1e-8) +
            (1 - y) * np.log(1 - h + 1e-8)
        )
        return cost

    # --------------------------------------------------
    # Gradient Descent 
    # --------------------------------------------------
    def gradient_descent(self, X, y):
        m, n = X.shape
        theta = np.zeros(n)
        cost_history = []

        for i in range(self.iterations):
            h = self.sigmoid(X @ theta)
            error = h - y

            grad = (X.T @ error) / m
            theta -= self.alpha * grad

            cost = self.compute_cost(X, y, theta)
            cost_history.append(cost)

            if i % 100 == 0:
                print(f"Iteration {i:4d} | Cost = {cost:.6f}")

        return theta, cost_history

    # --------------------------------------------------
    # One-vs-All Training
    # --------------------------------------------------
    def fit(self, X, y):
        m, n = X.shape
        self.all_theta = np.zeros((self.num_labels, n))

        for label in range(self.num_labels):
            print(f"\nTraining classifier for digit {label}")
            y_binary = np.where(y == label, 1, 0)

            theta, _ = self.gradient_descent(X, y_binary)
            self.all_theta[label] = theta

    # --------------------------------------------------
    # Prediction
    # --------------------------------------------------
    def predict(self, X):
        probs = self.sigmoid(X @ self.all_theta.T)
        return np.argmax(probs, axis=1)

# %% [markdown]
# **Load Data**

# %%
with open('preprocessed_data.pkl', 'rb') as f:
    data = pickle.load(f)

X_train = data['X_train']
X_test  = data['X_test']
y_train = data['y_train']
y_test  = data['y_test']

# Add bias term
X_train = np.insert(X_train, 0, 1, axis=1)
X_test  = np.insert(X_test, 0, 1, axis=1)

print("Training set:", X_train.shape)
print("Testing set :", X_test.shape)
# Out:
# Training set: (8000, 785)
# Testing set : (2000, 785)

# %% [markdown]
# Train the Model

# %%
model = LogisticRegressionOVA(
    alpha=0.1,
    iterations=1000,
    num_labels=10
)

model.fit(X_train, y_train)
# Out:
# Training classifier for digit 0
# Iteration    0 | Cost = 0.606377
# Iteration  100 | Cost = 0.233773
# Iteration  200 | Cost = 0.201506
# Iteration  300 | Cost = 0.186260
# Iteration  400 | Cost = 0.176965
# Iteration  500 | Cost = 0.170541
# Iteration  600 | Cost = 0.165768
# Iteration  700 | Cost = 0.162050
# Iteration  800 | Cost = 0.159057
# Iteration  900 | Cost = 0.156585
#
# Training classifier for digit 1
# Iteration    0 | Cost = 0.563244
# Iteration  100 | Cost = 0.237021
# Iteration  200 | Cost = 0.207099
# Iteration  300 | Cost = 0.192308
# Iteration  400 | Cost = 0.183221
# Iteration  500 | Cost = 0.176911
# Iteration  600 | Cost = 0.172187
# Iteration  700 | Cost = 0.168471
# Iteration  800 | Cost = 0.165443
# Iteration  900 | Cost = 0.162910
#
# Training classifier for digit 2
# Iteration    0 | Cost = 0.579318
# Iteration  100 | Cost = 0.280824
# Iteration  200 | Cost = 0.250326
# Iteration  300 | Cost = 0.230477
# Iteration  400 | Cost = 0.216781
# Iteration  500 | Cost = 0.206829
# Iteration  600 | Cost = 0.199290
# Iteration  700 | Cost = 0.193386
# Iteration  800 | Cost = 0.188639
# Iteration  900 | Cost = 0.184737
#
# Training classifier for digit 3
# Iteration    0 | Cost = 0.600770
# Iteration  100 | Cost = 0.256180
# Iteration  200 | Cost = 0.217283
# Iteration  300 | Cost = 0.195723
# Iteration  400 | Cost = 0.181748
# Iteration  500 | Cost = 0.171788
# Iteration  600 | Cost = 0.164261
# Iteration  700 | Cost = 0.158339
# Iteration  800 | Cost = 0.153544
# Iteration  900 | Cost = 0.149574
#
# Training classifier for digit 4
# Iteration    0 | Cost = 0.584507
# Iteration  100 | Cost = 0.264995
# Iteration  200 | Cost = 0.232929
# Iteration  300 | Cost = 0.214870
# Iteration  400 | Cost = 0.203136
# Iteration  500 | Cost = 0.194811
# Iteration  600 | Cost = 0.188557
# Iteration  700 | Cost = 0.183665
# Iteration  800 | Cost = 0.179722
# Iteration  900 | Cost = 0.176466
#
# Training classifier for digit 5
# Iteration    0 | Cost = 0.585001
# Iteration  100 | Cost = 0.271019
# Iteration  200 | Cost = 0.241591
# Iteration  300 | Cost = 0.225045
# Iteration  400 | Cost = 0.214297
# Iteration  500 | Cost = 0.206605
# Iteration  600 | Cost = 0.200742
# Iteration  700 | Cost = 0.196077
# Iteration  800 | Cost = 0.192250
# Iteration  900 | Cost = 0.189037
#
# Training classifier for digit 6
# Iteration    0 | Cost = 0.592137
# Iteration  100 | Cost = 0.241471
# Iteration  200 | Cost = 0.202032
# Iteration  300 | Cost = 0.180194
# Iteration  400 | Cost = 0.165785
# Iteration  500 | Cost = 0.155335
# Iteration  600 | Cost = 0.147311
# Iteration  700 | Cost = 0.140911
# Iteration  800 | Cost = 0.135662
# Iteration  900 | Cost = 0.131265
#
# Training classifier for digit 7
# Iteration    0 | Cost = 0.573355
# Iteration  100 | Cost = 0.268729
# Iteration  200 | Cost = 0.242274
# Iteration  300 | Cost = 0.226906
# Iteration  400 | Cost = 0.216640
# Iteration  500 | Cost = 0.209221
# Iteration  600 | Cost = 0.203583
# Iteration  700 | Cost = 0.199144
# Iteration  800 | Cost = 0.195553
# Iteration  900 | Cost = 0.192583
#
# Training classifier for digit 8
# Iteration    0 | Cost = 0.599714
# Iteration  100 | Cost = 0.294671
# Iteration  200 | Cost = 0.272063
# Iteration  300 | Cost = 0.259408
# Iteration  400 | Cost = 0.251271
# Iteration  500 | Cost = 0.245477
# Iteration  600 | Cost = 0.241060
# Iteration  700 | Cost = 0.237536
# Iteration  800 | Cost = 0.234629
# Iteration  900 | Cost = 0.232174
#
# Training classifier for digit 9
# Iteration    0 | Cost = 0.576028
# Iteration  100 | Cost = 0.264965
# Iteration  200 | Cost = 0.233620
# Iteration  300 | Cost = 0.215647
# Iteration  400 | Cost = 0.203960
# Iteration  500 | Cost = 0.195679
# Iteration  600 | Cost = 0.189451
# Iteration  700 | Cost = 0.184566
# Iteration  800 | Cost = 0.180612
# Iteration  900 | Cost = 0.177332

# %% [markdown]
# Predictions

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# **Evaluation Metrics (Accuracy, Precision, Recall, F1 , Confusion Matrix)**

# %%
accuracy  = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall    = recall_score(y_test, y_pred, average='macro')
f1        = f1_score(y_test, y_pred, average='macro')

print("📊 MODEL PERFORMANCE")
print("====================")
print(f"Accuracy : {accuracy*100:.2f}%")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1-score : {f1:.4f}")

#================================================
# Confusion Matrix
#================================================

cm = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:\n", cm)
print("=================================================")

# disp = ConfusionMatrixDisplay(
#     confusion_matrix=cm,
#     display_labels=[str(i) for i in range(10)]
# )

# plt.figure(figsize=(8, 8))
# disp.plot(cmap='Blues', values_format='d')
# plt.title("Confusion Matrix - Logistic Regression (One-vs-All)")
# plt.show()
# Out:
# 📊 MODEL PERFORMANCE
# ====================
# Accuracy : 74.20%
# Precision: 0.7440
# Recall   : 0.7420
# F1-score : 0.7408
#
# Confusion Matrix:
#  [[158  11   1   2   8   4   8   0   2   6]
#  [  3 157   5   7   3   3   5   9   6   2]
#  [  3   7 146  11   7   1   3   7   5  10]
#  [  6   3   7 157  11   2   0   3   7   4]
#  [  6   8   3   2 151   3  10   4   6   7]
#  [  8   6   1   4   5 146  17   3   8   2]
#  [  0  13   0   1   1  11 170   1   3   0]
#  [  3  13   7   3   8   3   3 130   7  23]
#  [ 10   7   3   9  16  16   9   8 117   5]
#  [  6   4   3   9  12   0   0  11   3 152]]
# =================================================

# %% [markdown]
# hyperparameter_sensitivity_analysis

# %%
def hyperparameter_sensitivity_analysis(
    X_train, y_train, X_test, y_test,
    iterations=1000,
    num_labels=10
):
    """
    Study the impact of different learning rates (alpha)
    """

    learning_rates = {
        "LowerALpha"   : 0.05,
        "BaseAlpha"    : 0.1,
        "HigerAlpha"    : 0.2
    }

    results = {}

    for name, alpha in learning_rates.items():
        print(f"\n==============================")
        print(f"Training with {name} (alpha = {alpha})")
        print(f"==============================")

        model = LogisticRegressionOVA(
            alpha=alpha,
            iterations=iterations,
            num_labels=num_labels
        )

        model.fit(X_train, y_train)

        y_pred = model.predict(X_test)
        acc = accuracy_score(y_test, y_pred)

        results[name] = acc

        print(f"Accuracy with {name}: {acc * 100:.2f}%")

    return results

# %%
results = hyperparameter_sensitivity_analysis(
    X_train, y_train,
    X_test, y_test,
    iterations=202,
    num_labels=10
)


print("\n📌 Hyperparameter Sensitivity Results")
print("===================================")
for k, v in results.items():
    print(f"{k:<15}: {v*100:.2f}%")
# Out:
# ==============================
# Training with LowerALpha (alpha = 0.05)
# ==============================
#
# Training classifier for digit 0
# Iteration    0 | Cost = 0.364381
# Iteration  100 | Cost = 0.270407
# Iteration  200 | Cost = 0.234088
#
# Training classifier for digit 1
# Iteration    0 | Cost = 0.339386
# Iteration  100 | Cost = 0.267727
# Iteration  200 | Cost = 0.237336
#
# Training classifier for digit 2
# Iteration    0 | Cost = 0.348564
# Iteration  100 | Cost = 0.302651
# Iteration  200 | Cost = 0.281024
#
# Training classifier for digit 3
# Iteration    0 | Cost = 0.361045
# Iteration  100 | Cost = 0.290165
# Iteration  200 | Cost = 0.256469
#
# Training classifier for digit 4
# Iteration    0 | Cost = 0.351598
# Iteration  100 | Cost = 0.292464
# Iteration  200 | Cost = 0.265253
#
# Training classifier for digit 5
# Iteration    0 | Cost = 0.351864
# Iteration  100 | Cost = 0.296071
# Iteration  200 | Cost = 0.271237
#
# Training classifier for digit 6
# Iteration    0 | Cost = 0.356047
# Iteration  100 | Cost = 0.277664
# Iteration  200 | Cost = 0.241791
#
# Training classifier for digit 7
# Iteration    0 | Cost = 0.345152
# Iteration  100 | Cost = 0.291531
# Iteration  200 | Cost = 0.268944
#
# Training classifier for digit 8
# Iteration    0 | Cost = 0.360398
# Iteration  100 | Cost = 0.313570
# Iteration  200 | Cost = 0.294837
#
# Training classifier for digit 9
# Iteration    0 | Cost = 0.346685
# Iteration  100 | Cost = 0.291012
# Iteration  200 | Cost = 0.265208
# Accuracy with LowerALpha: 67.60%
#
# ==============================
# Training with BaseAlpha (alpha = 0.1)
# ==============================
#
# Training classifier for digit 0
# Iteration    0 | Cost = 0.606377
# Iteration  100 | Cost = 0.233773
# Iteration  200 | Cost = 0.201506
#
# Training classifier for digit 1
# Iteration    0 | Cost = 0.563244
# Iteration  100 | Cost = 0.237021
# Iteration  200 | Cost = 0.207099
#
# Training classifier for digit 2
# Iteration    0 | Cost = 0.579318
# Iteration  100 | Cost = 0.280824
# Iteration  200 | Cost = 0.250326
#
# Training classifier for digit 3
# Iteration    0 | Cost = 0.600770
# Iteration  100 | Cost = 0.256180
# Iteration  200 | Cost = 0.217283
#
# Training classifier for digit 4
# Iteration    0 | Cost = 0.584507
# Iteration  100 | Cost = 0.264995
# Iteration  200 | Cost = 0.232929
#
# Training classifier for digit 5
# Iteration    0 | Cost = 0.585001
# Iteration  100 | Cost = 0.271019
# Iteration  200 | Cost = 0.241591
#
# Training classifier for digit 6
# Iteration    0 | Cost = 0.592137
# Iteration  100 | Cost = 0.241471
# Iteration  200 | Cost = 0.202032
#
# Training classifier for digit 7
# Iteration    0 | Cost = 0.573355
# Iteration  100 | Cost = 0.268729
# Iteration  200 | Cost = 0.242274
#
# Training classifier for digit 8
# Iteration    0 | Cost = 0.599714
# Iteration  100 | Cost = 0.294671
# Iteration  200 | Cost = 0.272063
#
# Training classifier for digit 9
# Iteration    0 | Cost = 0.576028
# Iteration  100 | Cost = 0.264965
# Iteration  200 | Cost = 0.233620
# Accuracy with BaseAlpha: 69.15%
#
# ==============================
# Training with HigerAlpha (alpha = 0.2)
# ==============================
#
# Training classifier for digit 0
# Iteration    0 | Cost = 1.198357
# Iteration  100 | Cost = 0.210441
# Iteration  200 | Cost = 0.176314
#
# Training classifier for digit 1
# Iteration    0 | Cost = 1.114214
# Iteration  100 | Cost = 0.208997
# Iteration  200 | Cost = 0.182914
#
# Training classifier for digit 2
# Iteration    0 | Cost = 1.145813
# Iteration  100 | Cost = 0.268045
# Iteration  200 | Cost = 0.228702
#
# Training classifier for digit 3
# Iteration    0 | Cost = 1.188148
# Iteration  100 | Cost = 0.236305
# Iteration  200 | Cost = 0.186111
#
# Training classifier for digit 4
# Iteration    0 | Cost = 1.155584
# Iteration  100 | Cost = 0.247731
# Iteration  200 | Cost = 0.205593
#
# Training classifier for digit 5
# Iteration    0 | Cost = 1.156771
# Iteration  100 | Cost = 0.259261
# Iteration  200 | Cost = 0.223821
#
# Training classifier for digit 6
# Iteration    0 | Cost = 1.170812
# Iteration  100 | Cost = 0.216328
# Iteration  200 | Cost = 0.164824
#
# Training classifier for digit 7
# Iteration    0 | Cost = 1.133951
# Iteration  100 | Cost = 0.256995
# Iteration  200 | Cost = 0.224188
#
# Training classifier for digit 8
# Iteration    0 | Cost = 1.185365
# Iteration  100 | Cost = 0.293631
# Iteration  200 | Cost = 0.268686
#
# Training classifier for digit 9
# Iteration    0 | Cost = 1.139306
# Iteration  100 | Cost = 0.248492
# Iteration  200 | Cost = 0.208468
# Accuracy with HigerAlpha: 66.10%
#
# 📌 Hyperparameter Sensitivity Results
# ===================================
# LowerALpha     : 67.60%
# BaseAlpha      : 69.15%
# HigerAlpha     : 66.10%

# %% [markdown]
# 5-FOLD CROSS-VALIDATION

# %%
from sklearn.model_selection import KFold
import time

# =========================================================
# 5-Fold Cross Validation (NO Regularization)
# =========================================================
def k_fold_cross_validation(X, y, k=5, alpha=0.1, iterations=300):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)

    accuracy_list = []
    precision_list = []
    recall_list = []
    f1_list = []
    training_time_list = []

    fold = 1

    for train_idx, val_idx in kf.split(X):
        print(f"\n🔁 Fold {fold}/{k}")

        X_train_cv, X_val_cv = X[train_idx], X[val_idx]
        y_train_cv, y_val_cv = y[train_idx], y[val_idx]

        model = LogisticRegressionOVA(
            alpha=alpha,
            iterations=iterations,
            num_labels=10
        )

        start_time = time.time()
        model.fit(X_train_cv, y_train_cv)
        training_time_list.append(time.time() - start_time)

        y_pred_cv = model.predict(X_val_cv)

        accuracy_list.append(accuracy_score(y_val_cv, y_pred_cv))
        precision_list.append(precision_score(y_val_cv, y_pred_cv, average='macro'))
        recall_list.append(recall_score(y_val_cv, y_pred_cv, average='macro'))
        f1_list.append(f1_score(y_val_cv, y_pred_cv, average='macro'))

        fold += 1

    return {
        "accuracy": accuracy_list,
        "precision": precision_list,
        "recall": recall_list,
        "f1": f1_list,
        "time": training_time_list
    }

# %% [markdown]
# Run Cross-Validation

# %%
cv_results = k_fold_cross_validation(
    X_train,
    y_train,
    k=5,
    alpha=0.1,
    iterations=300   # reduced for time
)
# Out:
# 🔁 Fold 1/5
#
# Training classifier for digit 0
# Iteration    0 | Cost = 0.606684
# Iteration  100 | Cost = 0.233807
# Iteration  200 | Cost = 0.201758
#
# Training classifier for digit 1
# Iteration    0 | Cost = 0.574561
# Iteration  100 | Cost = 0.238712
# Iteration  200 | Cost = 0.208993
#
# Training classifier for digit 2
# Iteration    0 | Cost = 0.571982
# Iteration  100 | Cost = 0.277824
# Iteration  200 | Cost = 0.248249
#
# Training classifier for digit 3
# Iteration    0 | Cost = 0.599598
# Iteration  100 | Cost = 0.257039
# Iteration  200 | Cost = 0.218518
#
# Training classifier for digit 4
# Iteration    0 | Cost = 0.590590
# Iteration  100 | Cost = 0.268979
# Iteration  200 | Cost = 0.237213
#
# Training classifier for digit 5
# Iteration    0 | Cost = 0.583669
# Iteration  100 | Cost = 0.271365
# Iteration  200 | Cost = 0.242748
#
# Training classifier for digit 6
# Iteration    0 | Cost = 0.601835
# Iteration  100 | Cost = 0.243360
# Iteration  200 | Cost = 0.202943
#
# Training classifier for digit 7
# Iteration    0 | Cost = 0.575445
# Iteration  100 | Cost = 0.268347
# Iteration  200 | Cost = 0.241540
#
# Training classifier for digit 8
# Iteration    0 | Cost = 0.611096
# Iteration  100 | Cost = 0.298719
# Iteration  200 | Cost = 0.276179
#
# Training classifier for digit 9
# Iteration    0 | Cost = 0.565959
# Iteration  100 | Cost = 0.260911
# Iteration  200 | Cost = 0.230522
#
# 🔁 Fold 2/5
#
# Training classifier for digit 0
# Iteration    0 | Cost = 0.614159
# Iteration  100 | Cost = 0.237128
# Iteration  200 | Cost = 0.204656
#
# Training classifier for digit 1
# Iteration    0 | Cost = 0.565585
# Iteration  100 | Cost = 0.237801
# Iteration  200 | Cost = 0.207291
#
# Training classifier for digit 2
# Iteration    0 | Cost = 0.576013
# Iteration  100 | Cost = 0.280192
# Iteration  200 | Cost = 0.249728
#
# Training classifier for digit 3
# Iteration    0 | Cost = 0.607297
# Iteration  100 | Cost = 0.256981
# Iteration  200 | Cost = 0.217192
#
# Training classifier for digit 4
# Iteration    0 | Cost = 0.581467
# Iteration  100 | Cost = 0.263319
# Iteration  200 | Cost = 0.231308
#
# Training classifier for digit 5
# Iteration    0 | Cost = 0.584162
# Iteration  100 | Cost = 0.271957
# Iteration  200 | Cost = 0.242920
#
# Training classifier for digit 6
# Iteration    0 | Cost = 0.583948
# Iteration  100 | Cost = 0.240470
# Iteration  200 | Cost = 0.201776
#
# Training classifier for digit 7
# Iteration    0 | Cost = 0.570085
# Iteration  100 | Cost = 0.267440
# Iteration  200 | Cost = 0.241382
#
# Training classifier for digit 8
# Iteration    0 | Cost = 0.605157
# Iteration  100 | Cost = 0.296831
# Iteration  200 | Cost = 0.273950
#
# Training classifier for digit 9
# Iteration    0 | Cost = 0.568679
# Iteration  100 | Cost = 0.261834
# Iteration  200 | Cost = 0.230331
#
# 🔁 Fold 3/5
#
# Training classifier for digit 0
# Iteration    0 | Cost = 0.603812
# Iteration  100 | Cost = 0.230185
# Iteration  200 | Cost = 0.197414
#
# Training classifier for digit 1
# Iteration    0 | Cost = 0.550533
# Iteration  100 | Cost = 0.234542
# Iteration  200 | Cost = 0.205064
#
# Training classifier for digit 2
# Iteration    0 | Cost = 0.587308
# Iteration  100 | Cost = 0.282031
# Iteration  200 | Cost = 0.250114
#
# Training classifier for digit 3
# Iteration    0 | Cost = 0.595289
# Iteration  100 | Cost = 0.254685
# Iteration  200 | Cost = 0.216226
#
# Training classifier for digit 4
# Iteration    0 | Cost = 0.581832
# Iteration  100 | Cost = 0.262518
# Iteration  200 | Cost = 0.230096
#
# Training classifier for digit 5
# Iteration    0 | Cost = 0.596701
# Iteration  100 | Cost = 0.270469
# Iteration  200 | Cost = 0.238937
#
# Training classifier for digit 6
# Iteration    0 | Cost = 0.587594
# Iteration  100 | Cost = 0.239509
# Iteration  200 | Cost = 0.200270
#
# Training classifier for digit 7
# Iteration    0 | Cost = 0.565749
# Iteration  100 | Cost = 0.266893
# Iteration  200 | Cost = 0.240643
#
# Training classifier for digit 8
# Iteration    0 | Cost = 0.589790
# Iteration  100 | Cost = 0.290513
# Iteration  200 | Cost = 0.267845
#
# Training classifier for digit 9
# Iteration    0 | Cost = 0.589093
# Iteration  100 | Cost = 0.269295
# Iteration  200 | Cost = 0.237198
#
# 🔁 Fold 4/5
#
# Training classifier for digit 0
# Iteration    0 | Cost = 0.605315
# Iteration  100 | Cost = 0.233191
# Iteration  200 | Cost = 0.200731
#
# Training classifier for digit 1
# Iteration    0 | Cost = 0.567178
# Iteration  100 | Cost = 0.237243
# Iteration  200 | Cost = 0.206924
#
# Training classifier for digit 2
# Iteration    0 | Cost = 0.580984
# Iteration  100 | Cost = 0.280045
# Iteration  200 | Cost = 0.248853
#
# Training classifier for digit 3
# Iteration    0 | Cost = 0.591907
# Iteration  100 | Cost = 0.255192
# Iteration  200 | Cost = 0.217064
#
# Training classifier for digit 4
# Iteration    0 | Cost = 0.586942
# Iteration  100 | Cost = 0.267697
# Iteration  200 | Cost = 0.235575
#
# Training classifier for digit 5
# Iteration    0 | Cost = 0.587058
# Iteration  100 | Cost = 0.271702
# Iteration  200 | Cost = 0.242149
#
# Training classifier for digit 6
# Iteration    0 | Cost = 0.587747
# Iteration  100 | Cost = 0.240783
# Iteration  200 | Cost = 0.201611
#
# Training classifier for digit 7
# Iteration    0 | Cost = 0.571957
# Iteration  100 | Cost = 0.268229
# Iteration  200 | Cost = 0.241440
#
# Training classifier for digit 8
# Iteration    0 | Cost = 0.606964
# Iteration  100 | Cost = 0.296855
# Iteration  200 | Cost = 0.273924
#
# Training classifier for digit 9
# Iteration    0 | Cost = 0.574580
# Iteration  100 | Cost = 0.264599
# Iteration  200 | Cost = 0.233168
#
# 🔁 Fold 5/5
#
# Training classifier for digit 0
# Iteration    0 | Cost = 0.601832
# Iteration  100 | Cost = 0.233172
# Iteration  200 | Cost = 0.200967
#
# Training classifier for digit 1
# Iteration    0 | Cost = 0.558209
# Iteration  100 | Cost = 0.235826
# Iteration  200 | Cost = 0.205819
#
# Training classifier for digit 2
# Iteration    0 | Cost = 0.580140
# Iteration  100 | Cost = 0.282626
# Iteration  200 | Cost = 0.252605
#
# Training classifier for digit 3
# Iteration    0 | Cost = 0.609562
# Iteration  100 | Cost = 0.255811
# Iteration  200 | Cost = 0.215809
#
# Training classifier for digit 4
# Iteration    0 | Cost = 0.581686
# Iteration  100 | Cost = 0.261068
# Iteration  200 | Cost = 0.228446
#
# Training classifier for digit 5
# Iteration    0 | Cost = 0.573165
# Iteration  100 | Cost = 0.268016
# Iteration  200 | Cost = 0.238945
#
# Training classifier for digit 6
# Iteration    0 | Cost = 0.599416
# Iteration  100 | Cost = 0.242011
# Iteration  200 | Cost = 0.201878
#
# Training classifier for digit 7
# Iteration    0 | Cost = 0.583416
# Iteration  100 | Cost = 0.271528
# Iteration  200 | Cost = 0.244568
#
# Training classifier for digit 8
# Iteration    0 | Cost = 0.585258
# Iteration  100 | Cost = 0.288808
# Iteration  200 | Cost = 0.266004
#
# Training classifier for digit 9
# Iteration    0 | Cost = 0.581477
# Iteration  100 | Cost = 0.266920
# Iteration  200 | Cost = 0.235035

# %% [markdown]
# Mean ± Std Report

# %%
print("\n📊 5-FOLD CROSS-VALIDATION RESULTS (Mean ± Std)")
print("=============================================")

for metric in cv_results:
    mean = np.mean(cv_results[metric])
    std  = np.std(cv_results[metric])
    print(f"{metric.capitalize():10s}: {mean:.4f} ± {std:.4f}")
# Out:
# 📊 5-FOLD CROSS-VALIDATION RESULTS (Mean ± Std)
# =============================================
# Accuracy  : 0.6975 ± 0.0139
# Precision : 0.6979 ± 0.0140
# Recall    : 0.6976 ± 0.0136
# F1        : 0.6956 ± 0.0141
# Time      : 176.2878 ± 2.9360
